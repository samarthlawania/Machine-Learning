# %% [markdown]
# <a href="https://colab.research.google.com/github/samarthlawania/Machine-Learning/blob/main/Tensor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
a = np.array(4)

# %%
a
# Out:
# array(4)

# %%
a.ndim
# Out:
# 0

# %% [markdown]
# **Axis** is same as the rank or independent vectors in an matrix
#
# Examples of tensors:-
#
# **1D tensor** :- A data of student (CGPA,AGE,GENDER,PACKAGE) is a 1D tensor
#
# **2D tensor**:- The combination of 1D tensors like the data of whiole class is the 2D tensor
#
# **3D tensor**:- These are the least founded in the field of Data science but the main exmple you can fdind out in NLP.
#
# **4D tensor**:- The real life example of the 4D tenossrs is image coz images are the combination of RGB which are nothing but pixel and 1 Pixel is a 3D tensor coz it contains a list of RGB tensor which are 2D tensor.
#
# **5D tensor**:- The real life example of 5D tensotr are videos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %% [markdown]
# #Steps
#
#
# Preprocessor + EDA + Features Selection
#
# Extract input and output cols
#
# Scale the value
#
# Train test spit
#
# Train the model
#
# Execute the model/ model selection
#
# Deploy the model

# %%
df.shape
# Out:
# (100, 4)

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0
