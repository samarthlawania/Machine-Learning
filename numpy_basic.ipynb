# %% [markdown]
# <a href="https://colab.research.google.com/github/samarthlawania/Machine-Learning/blob/main/numpy_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
a = np.array([[1,2,3],[4,5,6]])
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
b = np.array([[4,5,6],[7,8,9]])
b
# Out:
# array([[4, 5, 6],
#        [7, 8, 9]])

# %%
print(a+b)
# Out:
# [[ 5  7  9]
#  [11 13 15]]

# %%
print(a-b)
# Out:
# [[-3 -3 -3]
#  [-3 -3 -3]]

# %%
print(a**2)
# Out:
# [[ 1  4  9]
#  [16 25 36]]

# %%
print(b**2)
# Out:
# [[16 25 36]
#  [49 64 81]]

# %%
print(a==2)
# Out:
# [[False  True False]
#  [False False False]]

# %%
np.sqrt(b)
# Out:
# array([[2.        , 2.23606798, 2.44948974],
#        [2.64575131, 2.82842712, 3.        ]])

# %%
np.tan(a)
# Out:
# array([[ 1.55740772, -2.18503986, -0.14254654],
#        [ 1.15782128, -3.38051501, -0.29100619]])

# %%
arr = np.array([[1,2],[3,4],[5,6]])

# %%
arr.reshape(2,3)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr.flatten()
# Out:
# array([1, 2, 3, 4, 5, 6])
